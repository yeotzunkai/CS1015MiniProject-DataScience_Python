# %% [markdown]
# ## Effect of car features on car price?
# ## How does the brand affect the price?
# ## Does popularity of the car affect the price?
# ## Are you selling your car for what it is worth?
# ## Are you buying an overpriced car?
# ## Can you get a cheaper car with similar features?

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
import import_ipynb
import CleanDataset

# %%
Data = pd.read_csv("data.csv")
Data = RemoveNullNumData(Data)
Data
# Out:
# The feature which contain missing values are
#  ['Engine Fuel Type', 'Engine HP', 'Engine Cylinders', 'Number of Doors', 'Market Category']
# Amount of rows removed with null values: 32.15%
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# ...

# %%
#Importing the dataset
Data = pd.read_csv("data.csv")
Data.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
MSRP = pd.DataFrame(Data[["MSRP"]])
Make = pd.DataFrame(Data[["Make"]])
Popularity = Data[["Popularity"]]

# %% [markdown]
# ## How does the brand affect the price?

# %% [markdown]
# ### The brand does affect the price of the car with certain prestigious brands (Bugatti, Lamborghini, Ferrari, etc...) which have a higher mean than others.

# %%
sb.set(rc = {'figure.figsize':(20,20)})
sb.boxplot(data=Data, x="MSRP", y="Make", orient="h",showfliers=False)
# Out:
# <AxesSubplot:xlabel='MSRP', ylabel='Make'>

# %% [markdown]
# ## How does the popularity affect the price?

# %%
sb.jointplot(data = Data, x = "MSRP", y = "Popularity", height = 12)

# %%
Corr1 = Data["MSRP"]
Corr2 = Data["Popularity"]
correlation = Corr2.corr(Corr1)
print(correlation)
# Out:
# -0.04847623245504416

# %% [markdown]
# ### From the jointplot and the correlation, the popularity car does not affect the price
